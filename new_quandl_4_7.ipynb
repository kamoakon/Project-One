# %%
import quandl
quandl.ApiConfig.api_key = '4nyydq5k_sPU89Nkvi_Q'

# %%
apple_stock = quandl.get_table('WIKI/PRICES', ticker="AAPL",
                               date = {'gte': '2018-01-01', 'lte': '2018-04-05'}, paginate=True)

apple_stock.set_index(["date"], inplace = True)
apple_stock.head(100)
# Out:
#            ticker     open      high       low    close      volume  \
# date
# 2018-01-02   AAPL  170.160  172.3000  169.2600  172.260  25048048.0
# 2018-01-03   AAPL  172.530  174.5500  171.9600  172.230  28819653.0
# 2018-01-04   AAPL  172.540  173.4700  172.0800  173.030  22211345.0
# 2018-01-05   AAPL  173.440  175.3700  173.0500  175.000  23016177.0
# 2018-01-08   AAPL  174.350  175.6100  173.9300  174.350  20134092.0
# 2018-01-09   AAPL  174.550  175.0600  173.4100  174.330  21262614.0
# 2018-01-10   AAPL  173.160  174.3000  173.0000  174.290  23589129.0
# 2018-01-11   AAPL  174.590  175.4886  174.4900  175.280  17523256.0
# 2018-01-12   AAPL  176.180  177.3600  175.6500  177.090  25039531.0
# 2018-01-16   AAPL  177.900  179.3900  176.1400  176.190  29159005.0
# 2018-01-17   AAPL  176.150  179.2500  175.0700  179.100  32752734.0
# 2018-01-18   AAPL  179.370  180.1000  178.2500  179.260  30234512.0
# 2018-01-19   AAPL  178.610  179.5800  177.4100  178.460  30827809.0
# ...

# %%
#quandl.get('NS1/AMZN', column_index='1')
apple_sent = quandl.get('NS1/AAPL_US')
apple_sent.head(10)
# Out:
#             Sentiment  Sentiment High  Sentiment Low  News Volume  News Buzz
# Date
# 2013-01-01        1.0             5.0           -4.0         48.0       10.0
# 2013-01-02       -1.0             4.0           -5.0         53.0       10.0
# 2013-01-03       -1.0             4.0           -5.0         44.0       10.0
# 2013-01-04        1.0             5.0           -3.0         59.0       10.0
# 2013-01-05        4.0             4.0            4.0          2.0        5.0
# 2013-01-06        1.0             4.0           -3.0         10.0        1.0
# 2013-01-07       -1.0             4.0           -4.0         53.0        9.0
# 2013-01-08       -1.0             4.0           -4.0         50.0       10.0
# 2013-01-09       -1.0             4.0           -4.0         40.0       10.0
# 2013-01-10        2.0             5.0           -3.0         73.0       10.0

# %%
merge_apple = apple_sent.merge(apple_stock, how = "inner", left_index = True, right_index = True)
merge_apple.head(200)
# Out:
#             Sentiment  Sentiment High  Sentiment Low  News Volume  News Buzz  \
# 2018-01-02      4.000           5.000          3.000         49.0        3.0
# 2018-01-03      4.000           5.000          4.000         41.0        3.0
# 2018-01-04      4.000           5.000          4.000         21.0        2.0
# 2018-01-05      4.000           5.000          4.000         64.0        9.0
# 2018-01-08      4.000           5.000          4.000         74.0       10.0
# 2018-01-09      4.000           4.000          4.000         52.0        8.0
# 2018-01-10      4.000           5.000          4.000         31.0        5.0
# 2018-01-11      4.000           4.000          4.000         28.0        4.0
# 2018-01-12      4.000           4.000          4.000         22.0        3.0
# 2018-01-16      2.000           4.000         -1.000         15.0        3.0
# 2018-01-17      2.000           5.000         -1.000          9.0        3.0
# ...

# %%
# Out:
#   File "<ipython-input-15-df1308dd3bef>", line 1
#     https://www.quandl.com/api/v3/datasets/NS1/WBA_US?api_key=4nyydq5k_sPU89Nkvi_Q
#            ^
# SyntaxError: invalid syntax

# %%
quandl_get_df = quandl.get('NS1/AAPL_US')
quandl_get_df.tail(100)
# Out:
#             Sentiment  Sentiment High  Sentiment Low  News Volume  News Buzz
# Date
# 2017-12-28      2.000           5.000         -2.000         95.0        7.0
# 2017-12-29      2.000           5.000         -2.000         68.0        5.0
# 2017-12-30      4.000           5.000          4.000          5.0        2.0
# 2017-12-31      4.000           5.000          4.000         14.0        3.0
# 2018-01-01      4.000           5.000          4.000         19.0        2.0
# 2018-01-02      4.000           5.000          3.000         49.0        3.0
# 2018-01-03      4.000           5.000          4.000         41.0        3.0
# 2018-01-04      4.000           5.000          4.000         21.0        2.0
# 2018-01-05      4.000           5.000          4.000         64.0        9.0
# 2018-01-06      4.000           5.000          3.000         43.0       10.0
# 2018-01-07      5.000           5.000          4.000          9.0       10.0
# ...
